# %% [markdown]
# <a href="https://colab.research.google.com/github/Andrea4-sr/mlnlp_ex5/blob/andrea/mlnlp_ex5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""Exercise 5: Sequence and Anger Regression using Transformers"""
# Out:
# 'Exercise 5: Sequence and Anger Regression using Transformers'

# %%
# !pip install transformers datasets sklearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.5 MB 8.9 MB/s
# ...
#      |████████████████████████████████| 451 kB 31.9 MB/s
# ...
#      |████████████████████████████████| 182 kB 54.7 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 15.3 MB/s
# ...
#      |████████████████████████████████| 115 kB 44.6 MB/s
# ...
#      |████████████████████████████████| 212 kB 56.1 MB/s
# ...
#      |████████████████████████████████| 127 kB 47.5 MB/s
# ...
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2344 sha256=ba097b91c6c03e8d3a7fac0ddf73bccd1b7d11421fbca5913cb9a96e4d6b4e76
#   Stored in directory: /root/.cache/pip/wheels/42/56/cc/4a8bf86613aafd5b7f1b310477667c1fca5c51c3ae4124a003
# Successfully built sklearn
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %%
# !pip install polyglot
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 126 kB 6.3 MB/s
# ...
#   Created wheel for polyglot: filename=polyglot-16.7.4-py2.py3-none-any.whl size=52580 sha256=87c0b925323ad12ce2b926ef7cc5feba5d6b2fb7f85b150d1bd325dca47fb342
#   Stored in directory: /root/.cache/pip/wheels/09/bc/67/75c9de8e9726460bc0b101ad225ad025cb8ce9e0759beb9d52
# Successfully built polyglot
# ...

# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import datasets
from datasets import load_dataset

# %%
polyglotner_train = datasets.load_dataset("polyglot_ner", split="train[:3001]")
# Out:
# WARNING:datasets.builder:No config specified, defaulting to: polyglot_ner/combined
# ...
# Generating train split:   0%|          | 0/21070925 [00:00<?, ? examples/s]
# Dataset polyglot_ner downloaded and prepared to /root/.cache/huggingface/datasets/polyglot_ner/combined/1.0.0/bb2e45c90cd345c87dfd757c8e2b808b78b0094543b511ac49bc0129699609c1. Subsequent calls will reuse this data.

# %%
polyglotner_train_1000 = datasets.load_dataset('polyglot_ner', split='train[3001:4002]')
# Out:
# ...
# WARNING:datasets.builder:No config specified, defaulting to: polyglot_ner/combined
# ...
# Generating train split:   0%|          | 0/21070925 [00:00<?, ? examples/s]
